# %%
import cv2
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):
    plt.imshow(img),plt.xticks([]),plt.yticks([])
    plt.show()

    # Convert the image to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    edges = cv2.Canny(image=img_blur, threshold1=260, threshold2=400) # Canny Edge Detection
    plt.xticks([])
    plt.yticks([])
    plt.imshow(edges, cmap='viridis')
    cv2.imwrite('..\Figures\Bubble\Input_for_polar\Canny_bubb_858.png',edges)
    plt.savefig('..\Figures\Bubble\Canny_edge\Canny_bubb_858.png', dpi=600, transparent = True, bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    

image = cv2.imread(r'..\Figures\Bubble\Original_defects\858.jpg') # Read the original image
canny_edge_detection_bubble(image) # Display original image

# %%
def canny_edge_detection_bubble(img):
    plt.imshow(img),plt.xticks([]),plt.yticks([])
    plt.show()

    # Convert the image to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    edges = cv2.Canny(image=img_blur, threshold1=295, threshold2=300) # Canny Edge Detection
    plt.xticks([])
    plt.yticks([])
    plt.imshow(edges, cmap='viridis')
    cv2.imwrite('..\Figures\Bubble\Input_for_polar\Canny_bubb_19.png',edges)
    plt.savefig('..\Figures\Bubble\Canny_edge\Canny_bubb_19.png', dpi=600, transparent = True, bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    

image = cv2.imread(r'..\Figures\Bubble\Original_defects\19.jpg') # Read the original image
canny_edge_detection_bubble(image) # Display original image

# %%
def canny_edge_detection_bubble(img):
    plt.imshow(img),plt.xticks([]),plt.yticks([])
    plt.show()

    # Convert the image to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    edges = cv2.Canny(image=img_blur, threshold1=200, threshold2=380) # Canny Edge Detection
    plt.xticks([])
    plt.yticks([])
    plt.imshow(edges, cmap='viridis')
    cv2.imwrite('..\Figures\Bubble\Input_for_polar\Canny_bubb_337.png',edges)
    plt.savefig('..\Figures\Bubble\Canny_edge\Canny_bubb_337.png', dpi=600, transparent = True, bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    

image = cv2.imread(r'..\Figures\Bubble\Original_defects\337.jpg') # Read the original image
canny_edge_detection_bubble(image) # Display original image

# %%
def canny_edge_detection_bubble(img):
    plt.imshow(img),plt.xticks([]),plt.yticks([])
    plt.show()

    # Convert the image to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    edges = cv2.Canny(image=img_blur, threshold1=165, threshold2=300) # Canny Edge Detection
    plt.xticks([])
    plt.yticks([])
    plt.imshow(edges, cmap='viridis')
    cv2.imwrite('..\Figures\Bubble\Input_for_polar\Canny_bubb_3177.png',edges)
    plt.savefig('..\Figures\Bubble\Canny_edge\Canny_bubb_3177.png', dpi=600, transparent = True, bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    

image = cv2.imread(r'..\Figures\Bubble\Original_defects\3177.jpg') # Read the original image
canny_edge_detection_bubble(image) # Display original image

# %% [markdown]
# # Polar plot

# %%
from PIL import Image
import math
import numpy as np
from pathlib import Path
import os

root = Path(r'..\Figures\Bubble\Input_for_polar') # directory where original images are stored
assert root.is_dir() # make sure this directory is found
files = sorted(root.glob('*.png'), key=lambda file : file.name) # read files and sort by name so order is consistent

def polar_plot_bubble(inpath, outdir):
    image=Image.open(file)

    image_name=(os.path.basename(inpath))  
    plt.rc('xtick', labelsize=20)
    fig = plt.figure(1)
    ax = fig.add_subplot(111, projection='polar')
    
    for k in range(360):
        #convert the image into numpy array
        image_data=image.rotate(k)
        image_data=np.asarray(image_data)

        # Number of rows and columns in the image
        rows=np. size(image_data, 0)
        columns=np. size(image_data, 1)
        RowTotals = np.sum(image_data, axis=1) # Sum down the rows
        nz_row = np.nonzero(RowTotals) # non-zero (non-black) entries

        #Initialize an empty dictionary to store the row and column numbers of non zero entries
        emptyDict = {}

        #Compute the non zero entries (edges) 
        for i in range(np.array(nz_row).size):
            diff_row=[]
            element=(np.array(nz_row))[0][i]
            diff_row.append(element)

            diff_col=[]
            for j in range(columns):
                if (image_data[element][j]).any()!=0:
                    diff_col.append(j)

            emptyDict[tuple(diff_row)] = tuple(diff_col)

        #Compute the distance between the edges
        Distance=[]
        for row in emptyDict.keys():
            if len(emptyDict[row])>1:
                Distance.append(max(emptyDict[row])-min(emptyDict[row]))
            else:
                Distance.append(max(emptyDict[row]))

        theta=math.radians(k)
        rads = math.radians(np.mean(Distance))
        ax.set_yticklabels([])
        ax.yaxis.grid(False)
        ax.tick_params(pad=13)
        ax.xaxis.grid(color='orange', linestyle='--')
        ax.plot(theta, rads, 'go', linewidth=3, alpha=0.5)

    plt.savefig(outdir + image_name + str ('.png'), dpi=600,bbox_inches = 'tight')
    plt.show()
    return

output_root = r'..\Figures\Bubble\Polar\\' # place where pre-processed images will be stored
os.makedirs(output_root, exist_ok=True) # create output directory if it does not exist
for file in files:
    polar_plot_bubble(file, output_root)
