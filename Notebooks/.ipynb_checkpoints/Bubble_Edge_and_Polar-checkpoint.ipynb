# %% [markdown]
# # #Bubble edge detection

# %%
import cv2
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.savefig('D:\Yolo Notebooks\Bubble\Final\Canny_Bubb_original_858.png',dpi= 600, transparent = True, bbox_inches = 'tight', pad_inches = 0)
    plt.show()

    # Convert to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    edges = cv2.Canny(image=img_blur, threshold1=260, threshold2=400) # Canny Edge Detection
    plt.xticks([])
    plt.yticks([])
    plt.imshow(edges, cmap='viridis')
    cv2.imwrite('D:\Yolo Notebooks\Bubble\Final\Polar plots\Canny_bubb_858.png',edges)
    plt.savefig('D:\Yolo Notebooks\Bubble\Final\Canny_bubb_858.png', dpi=600, transparent = True, bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    
# Read the original image
image = cv2.imread(r'D:\Yolo Notebooks\Bubble\Defects\858.jpg') 
# Display original image
canny_edge_detection_bubble(image)

# %%
import cv2
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):

    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.savefig('D:\Yolo Notebooks\Bubble\Final\Canny_Bubb_original_19.png',dpi= 600, transparent = True, bbox_inches = 'tight', pad_inches = 0)
    plt.show()

    # Convert to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    edges = cv2.Canny(image=img_blur, threshold1=295, threshold2=300) # Canny Edge Detection
    plt.xticks([])
    plt.yticks([])
    plt.imshow(edges, cmap='viridis')
    cv2.imwrite('D:\Yolo Notebooks\Bubble\Final\Polar plots\Canny_bubb_19.png',edges)
    plt.savefig('D:\Yolo Notebooks\Bubble\Final\Canny_bubb_19.png', dpi=600, transparent = True, bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    
# Read the original image
image = cv2.imread(r'D:\Yolo Notebooks\Bubble\Defects\19.jpg') 
# Display original image
canny_edge_detection_bubble(image)

# %%
import cv2
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):

    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.savefig('D:\Yolo Notebooks\Bubble\Final\Canny_Bubb_original_337.png',dpi= 600, transparent = True, bbox_inches = 'tight', pad_inches = 0)
    plt.show()

    # Convert to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    edges = cv2.Canny(image=img_blur, threshold1=200, threshold2=380) # Canny Edge Detection
    plt.xticks([])
    plt.yticks([])
    plt.imshow(edges, cmap='viridis')
    cv2.imwrite('D:\Yolo Notebooks\Bubble\Final\Polar plots\Canny_bubb_337.png',edges)
    plt.savefig('D:\Yolo Notebooks\Bubble\Final\Canny_bubb_337.png', dpi=600, transparent = True, bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    
# Read the original image
image = cv2.imread(r'D:\Yolo Notebooks\Bubble\Defects\337.jpg') 
# Display original image
canny_edge_detection_bubble(image)

# %%
import cv2
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):

    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.savefig('D:\Yolo Notebooks\Bubble\Final\Canny_Bubb_original_3177.png',dpi= 600, transparent = True, bbox_inches = 'tight', pad_inches = 0)
    plt.show()

    # Convert to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    edges = cv2.Canny(image=img_blur, threshold1=165, threshold2=300) # Canny Edge Detection
    plt.xticks([])
    plt.yticks([])
    plt.imshow(edges, cmap='viridis')
    cv2.imwrite('D:\Yolo Notebooks\Bubble\Final\Polar plots\Canny_bubb_3177.png',edges)
    plt.savefig('D:\Yolo Notebooks\Bubble\Final\Canny_bubb_3177.png', dpi=600, transparent = True, bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    
# Read the original image
image = cv2.imread(r'D:\Yolo Notebooks\Bubble\Defects\3177.jpg') 
# Display original image
canny_edge_detection_bubble(image)

# %% [markdown]
# # Polar plot

# %%
from PIL import Image
import math
import numpy as np
from pathlib import Path
import os
import skimage.io
import matplotlib.pyplot as plt 
from PIL import Image

root = Path(r'D:\Yolo Notebooks\Bubble\Final\Polar plots') # directory where original images are stored
assert root.is_dir() # make sure this directory is found
files = sorted(root.glob('*.png'), key=lambda file : file.name) # read files and sort by name so order is consistent



def polar_plot_bubble(inpath, outdir):
    image=Image.open(file)

    image_name=(os.path.basename(inpath))
    #name = Path(inpath).name # get the filename of the image
    
    plt.rc('xtick', labelsize=20)
    fig = plt.figure(1)
    ax = fig.add_subplot(111, projection='polar')
    for k in range(360):
        #convert the image into numpy array
        image_data=image.rotate(k)
        image_data=np.asarray(image_data)

        # Number of rows and columns in the image
        rows=np. size(image_data, 0)
        columns=np. size(image_data, 1)

        # Sum down the rows
        RowTotals = np.sum(image_data, axis=1)

        # Now look for non-zero (non-black) entries
        nz_row = np.nonzero(RowTotals)
        #print(nz_row)

        #Initialize an empty dictionary to store the row and column numbers of non zero entries
        emptyDict = {}

        #Compute the non zero entries (edges) 
        for i in range(np.array(nz_row).size):
            diff_row=[]
            #print((np.array(nz_row)).size)
            element=(np.array(nz_row))[0][i]
            diff_row.append(element)

            diff_col=[]
            for j in range(columns):
                if (image_data[element][j]).any()!=0:
                    diff_col.append(j)

            emptyDict[tuple(diff_row)] = tuple(diff_col)

        #Compute the distance between the edges
        Distance=[]
        for row in emptyDict.keys():
            if len(emptyDict[row])>1:
                Distance.append(max(emptyDict[row])-min(emptyDict[row]))
            else:
                Distance.append(max(emptyDict[row]))

        #print(rads)
        theta=math.radians(k)
        #print(theta)

        # Plot a circle with radius 2 using polar form
        rads = math.radians(np.mean(Distance))
        ax.set_yticklabels([])
        ax.yaxis.grid(False)
        ax.tick_params(pad=13)
        ax.xaxis.grid(color='orange', linestyle='--')
        ax.plot(theta, rads, 'go', linewidth=3, alpha=0.5)


    # Display the Polar plot
    #plt.savefig(os.path.join(outdir, + image_name + str ('.png')))
    plt.savefig(outdir + image_name + str ('.png'), dpi=600,bbox_inches = 'tight')
    #plt.savefig((image_name + str ('.png')).format(outdir))
    plt.show()


    # Display the Polar plot
    #plt.savefig('E:\yolov5_defect_detection\Results\Polar_plots\Bubble\Bubble polar plot.png')
    #skimage.io.imsave(Path(outdir, name), plt.polar(theta,rads,'go',alpha=0.5)) # save image to disk
    plt.show()
    return

output_root = r'D:\Yolo Notebooks\Bubble\Final\Polar plots\\' # place where pre-processed images will be stored
os.makedirs(output_root, exist_ok=True) # create output directory if it does not exist
for file in files:
    polar_plot_bubble(file, output_root)
