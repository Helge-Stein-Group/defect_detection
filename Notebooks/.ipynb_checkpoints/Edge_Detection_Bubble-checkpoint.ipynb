# %% [markdown]
# # #Bubble edge detection

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('science')
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):
    plt.subplot(331),plt.imshow(img,cmap = 'gray')
    plt.title('Original Image'), plt.xticks([]), plt.yticks([])
    plt.show()
    # Convert to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    # Canny Edge Detection
    edges = cv2.Canny(image=img_blur, threshold1=260, threshold2=405) # Canny Edge Detection
    # Display Canny Edge Detection Image

    plt.subplot(335),plt.imshow(edges)
    plt.title('Canny Edge Detection'), plt.xticks([]), plt.yticks([])
    plt.show()
    cv2.imwrite(r'E:\yolov5_defect_detection\Results\Edge_Detection\Bubble\858.png', edges)
    
# Read the original image
image = cv2.imread(r'E:\yolov5_defect_detection\yolov5\runs\detect\exp10\crops\Bubb\858.jpg') 
# Display original image
canny_edge_detection_bubble(image)

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('science')
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):
    plt.subplot(331),plt.imshow(img,cmap = 'gray')
    plt.title('Original Image'), plt.xticks([]), plt.yticks([])
    plt.show()
    # Convert to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    # Canny Edge Detection
    edges = cv2.Canny(image=img_blur, threshold1=270, threshold2=380) # Canny Edge Detection
    # Display Canny Edge Detection Image

    plt.subplot(335),plt.imshow(edges)
    plt.title('Canny Edge Detection'), plt.xticks([]), plt.yticks([])
    plt.show()
    cv2.imwrite(r'E:\yolov5_defect_detection\Results\Edge_Detection\Bubble\19.png', edges)
    
# Read the original image
image = cv2.imread(r'E:\yolov5_defect_detection\yolov5\runs\detect\exp10\crops\Bubb\19.jpg') 
# Display original image
canny_edge_detection_bubble(image)

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('science')
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):
    plt.subplot(331),plt.imshow(img,cmap = 'gray')
    plt.title('Original Image'), plt.xticks([]), plt.yticks([])
    plt.show()
    # Convert to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    # Canny Edge Detection
    edges = cv2.Canny(image=img_blur, threshold1=250, threshold2=350) # Canny Edge Detection
    # Display Canny Edge Detection Image

    plt.subplot(335),plt.imshow(edges)
    plt.title('Canny Edge Detection'), plt.xticks([]), plt.yticks([])
    plt.show()
    cv2.imwrite(r'E:\yolov5_defect_detection\Results\Edge_Detection\Bubble\186.png', edges)
    
# Read the original image
image = cv2.imread(r'E:\yolov5_defect_detection\yolov5\runs\detect\exp10\crops\Bubb\186.jpg') 
# Display original image
canny_edge_detection_bubble(image)

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('science')
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):
    plt.subplot(331),plt.imshow(img,cmap = 'gray')
    plt.title('Original Image'), plt.xticks([]), plt.yticks([])
    plt.show()
    # Convert to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    # Canny Edge Detection
    edges = cv2.Canny(image=img_blur, threshold1=200, threshold2=380) # Canny Edge Detection
    # Display Canny Edge Detection Image

    plt.subplot(335),plt.imshow(edges)
    plt.title('Canny Edge Detection'), plt.xticks([]), plt.yticks([])
    plt.show()
    cv2.imwrite(r'E:\yolov5_defect_detection\Results\Edge_Detection\Bubble\337.png', edges)
    
# Read the original image
image = cv2.imread(r'E:\yolov5_defect_detection\yolov5\runs\detect\exp10\crops\Bubb\337.jpg') 
# Display original image
canny_edge_detection_bubble(image)

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('science')
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):
    plt.subplot(331),plt.imshow(img,cmap = 'gray')
    plt.title('Original Image'), plt.xticks([]), plt.yticks([])
    plt.show()
    # Convert to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    # Canny Edge Detection
    edges = cv2.Canny(image=img_blur, threshold1=50, threshold2=300) # Canny Edge Detection
    # Display Canny Edge Detection Image

    plt.subplot(335),plt.imshow(edges)
    plt.title('Canny Edge Detection'), plt.xticks([]), plt.yticks([])
    plt.show()
    cv2.imwrite(r'E:\yolov5_defect_detection\Results\Edge_Detection\Bubble\507.png', edges)
    
# Read the original image
image = cv2.imread(r'E:\yolov5_defect_detection\yolov5\runs\detect\exp10\crops\Bubb\507.jpg') 
# Display original image
canny_edge_detection_bubble(image)

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('science')
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):
    plt.subplot(331),plt.imshow(img,cmap = 'gray')
    plt.title('Original Image'), plt.xticks([]), plt.yticks([])
    plt.show()
    # Convert to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    # Canny Edge Detection
    edges = cv2.Canny(image=img_blur, threshold1=180, threshold2=400) # Canny Edge Detection
    # Display Canny Edge Detection Image

    plt.subplot(335),plt.imshow(edges)
    plt.title('Canny Edge Detection'), plt.xticks([]), plt.yticks([])
    plt.show()
    cv2.imwrite(r'E:\yolov5_defect_detection\Results\Edge_Detection\Bubble\733.png', edges)
    
# Read the original image
image = cv2.imread(r'E:\yolov5_defect_detection\yolov5\runs\detect\exp10\crops\Bubb\733.jpg') 
# Display original image
canny_edge_detection_bubble(image)

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('science')
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):
    plt.subplot(331),plt.imshow(img,cmap = 'gray')
    plt.title('Original Image'), plt.xticks([]), plt.yticks([])
    plt.show()
    # Convert to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    # Canny Edge Detection
    edges = cv2.Canny(image=img_blur, threshold1=130, threshold2=300) # Canny Edge Detection
    # Display Canny Edge Detection Image

    plt.subplot(335),plt.imshow(edges)
    plt.title('Canny Edge Detection'), plt.xticks([]), plt.yticks([])
    plt.show()
    cv2.imwrite(r'E:\yolov5_defect_detection\Results\Edge_Detection\Bubble\414.png', edges)
    
# Read the original image
image = cv2.imread(r'E:\yolov5_defect_detection\yolov5\runs\detect\exp10\crops\Bubb\414.jpg') 
# Display original image
canny_edge_detection_bubble(image)

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('science')
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):
    plt.subplot(331),plt.imshow(img,cmap = 'gray')
    plt.title('Original Image'), plt.xticks([]), plt.yticks([])
    plt.show()
    # Convert to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    # Canny Edge Detection
    edges = cv2.Canny(image=img_blur, threshold1=130, threshold2=330) # Canny Edge Detection
    # Display Canny Edge Detection Image

    plt.subplot(335),plt.imshow(edges)
    plt.title('Canny Edge Detection'), plt.xticks([]), plt.yticks([])
    plt.show()
    cv2.imwrite(r'E:\yolov5_defect_detection\Results\Edge_Detection\Bubble\2634.png', edges)
    
# Read the original image
image = cv2.imread(r'E:\yolov5_defect_detection\yolov5\runs\detect\exp10\crops\Bubb\2634.jpg') 
# Display original image
canny_edge_detection_bubble(image)

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('science')
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

def canny_edge_detection_bubble(img):
    plt.subplot(331),plt.imshow(img,cmap = 'gray')
    plt.title('Original Image'), plt.xticks([]), plt.yticks([])
    plt.show()
    # Convert to graycsale
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur the image for better edge detection
    img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
    # Canny Edge Detection
    edges = cv2.Canny(image=img_blur, threshold1=165, threshold2=300) # Canny Edge Detection
    # Display Canny Edge Detection Image

    plt.subplot(335),plt.imshow(edges)
    plt.title('Canny Edge Detection'), plt.xticks([]), plt.yticks([])
    plt.show()
    cv2.imwrite(r'E:\yolov5_defect_detection\Results\Edge_Detection\Bubble\3177.png', edges)
    
# Read the original image
image = cv2.imread(r'E:\yolov5_defect_detection\yolov5\runs\detect\exp10\crops\Bubb\3177.jpg') 
# Display original image
canny_edge_detection_bubble(image)
